# %% [markdown]
# <a href="https://colab.research.google.com/github/ShaikMusaSharif/Neural_networks/blob/main/Diabetes_prediction_using_ANN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# this is a binary class classification problem

# %%
import pandas as pd

# %%
df = pd.read_csv("/content/drive/MyDrive/diabetes.csv")

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
x = df.drop('Outcome',axis=1)
y = df["Outcome"]

# %%
x
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age
# 0                       0.627   50
# 1                       0.351   31
# 2                       0.672   32
# 3                       0.167   21
# 4                       2.288   33
# ..                        ...  ...
# 763                     0.171   63
# 764                     0.340   27
# 765                     0.245   30
# 766                     0.349   47
# 767                     0.315   23
#
# [768 rows x 8 columns]

# %%
y
# Out:
# 0      1
# 1      0
# 2      1
# 3      0
# 4      1
#       ..
# 763    0
# 764    0
# 765    0
# 766    1
# 767    0
# Name: Outcome, Length: 768, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2)

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
model = Sequential()
model.add(Dense(8,activation="relu",input_shape=(8,)))

# %%
model.add(Dense(8,activation="relu"))
model.add(Dense(1,activation="sigmoid"))

# %%
model.compile(loss="binary_crossentropy",optimizer="sgd",metrics=['accuracy'])

# %%
model.fit(x_train,y_train,epochs=50,batch_size=1,verbose=1)
# Out:
# Epoch 1/50
# 614/614 [==============================] - 3s 3ms/step - loss: 1.0073 - accuracy: 0.6450
# Epoch 2/50
# 614/614 [==============================] - 2s 3ms/step - loss: 0.6475 - accuracy: 0.6531
# Epoch 3/50
# 614/614 [==============================] - 1s 2ms/step - loss: 0.6467 - accuracy: 0.6531
# Epoch 4/50
# 614/614 [==============================] - 1s 2ms/step - loss: 0.6465 - accuracy: 0.6531
# Epoch 5/50
# 614/614 [==============================] - 1s 2ms/step - loss: 0.6464 - accuracy: 0.6531
# Epoch 6/50
# 614/614 [==============================] - 1s 2ms/step - loss: 0.6465 - accuracy: 0.6531
# Epoch 7/50
# 614/614 [==============================] - 1s 2ms/step - loss: 0.6466 - accuracy: 0.6531
# Epoch 8/50
# 614/614 [==============================] - 1s 2ms/step - loss: 0.6464 - accuracy: 0.6531
# Epoch 9/50
# 614/614 [==============================] - 1s 2ms/step - loss: 0.6463 - accuracy: 0.6531
# Epoch 10/50
# 614/614 [==============================] - 1s 2ms/step - loss: 0.6464 - accuracy: 0.6531
# Epoch 11/50
# 614/614 [==============================] - 2s 2ms/step - loss: 0.6457 - accuracy: 0.6531
# Epoch 12/50
# 614/614 [==============================] - 2s 3ms/step - loss: 0.6465 - accuracy: 0.6531
# Epoch 13/50
# 614/614 [==============================] - 2s 3ms/step - loss: 0.6466 - accuracy: 0.6531
# Epoch 14/50
# 614/614 [==============================] - 1s 2ms/step - loss: 0.6466 - accuracy: 0.6531
# Epoch 15/50
# 614/614 [==============================] - 1s 2ms/step - loss: 0.6465 - accuracy: 0.6531
# Epoch 16/50
# 614/614 [==============================] - 1s 2ms/step - loss: 0.6466 - accuracy: 0.6531
# Epoch 17/50
# 614/614 [==============================] - 1s 2ms/step - loss: 0.6464 - accuracy: 0.6531
# Epoch 18/50
# 614/614 [==============================] - 2s 2ms/step - loss: 0.6464 - accuracy: 0.6531
# Epoch 19/50
# 614/614 [==============================] - 1s 2ms/step - loss: 0.6466 - accuracy: 0.6531
# Epoch 20/50
# 614/614 [==============================] - 1s 2ms/step - loss: 0.6466 - accuracy: 0.6531
# Epoch 21/50
# 614/614 [==============================] - 2s 3ms/step - loss: 0.6465 - accuracy: 0.6531
# Epoch 22/50
# 614/614 [==============================] - 2s 4ms/step - loss: 0.6464 - accuracy: 0.6531
# Epoch 23/50
# 614/614 [==============================] - 2s 3ms/step - loss: 0.6464 - accuracy: 0.6531
# Epoch 24/50
# 614/614 [==============================] - 1s 2ms/step - loss: 0.6462 - accuracy: 0.6531
# Epoch 25/50
# 614/614 [==============================] - 1s 2ms/step - loss: 0.6459 - accuracy: 0.6531
# Epoch 26/50
# 614/614 [==============================] - 1s 2ms/step - loss: 0.6467 - accuracy: 0.6531
# Epoch 27/50
# 614/614 [==============================] - 1s 2ms/step - loss: 0.6464 - accuracy: 0.6531
# Epoch 28/50
# 614/614 [==============================] - 1s 2ms/step - loss: 0.6466 - accuracy: 0.6531
# Epoch 29/50
# 614/614 [==============================] - 1s 2ms/step - loss: 0.6455 - accuracy: 0.6531
# Epoch 30/50
# 614/614 [==============================] - 1s 2ms/step - loss: 0.6468 - accuracy: 0.6531
# Epoch 31/50
# 614/614 [==============================] - 2s 3ms/step - loss: 0.6464 - accuracy: 0.6531
# Epoch 32/50
# 614/614 [==============================] - 2s 3ms/step - loss: 0.6465 - accuracy: 0.6531
# Epoch 33/50
# 614/614 [==============================] - 2s 3ms/step - loss: 0.6466 - accuracy: 0.6531
# Epoch 34/50
# 614/614 [==============================] - 1s 2ms/step - loss: 0.6464 - accuracy: 0.6531
# Epoch 35/50
# 614/614 [==============================] - 1s 2ms/step - loss: 0.6464 - accuracy: 0.6531
# Epoch 36/50
# 614/614 [==============================] - 1s 2ms/step - loss: 0.6466 - accuracy: 0.6531
# Epoch 37/50
# 614/614 [==============================] - 1s 2ms/step - loss: 0.6464 - accuracy: 0.6531
# Epoch 38/50
# 614/614 [==============================] - 1s 2ms/step - loss: 0.6462 - accuracy: 0.6531
# Epoch 39/50
# 614/614 [==============================] - 1s 2ms/step - loss: 0.6466 - accuracy: 0.6531
# Epoch 40/50
# 614/614 [==============================] - 1s 2ms/step - loss: 0.6465 - accuracy: 0.6531
# Epoch 41/50
# 614/614 [==============================] - 2s 3ms/step - loss: 0.6466 - accuracy: 0.6531
# Epoch 42/50
# 614/614 [==============================] - 2s 3ms/step - loss: 0.6466 - accuracy: 0.6531
# Epoch 43/50
# 614/614 [==============================] - 2s 3ms/step - loss: 0.6466 - accuracy: 0.6531
# Epoch 44/50
# 614/614 [==============================] - 1s 2ms/step - loss: 0.6465 - accuracy: 0.6531
# Epoch 45/50
# 614/614 [==============================] - 1s 2ms/step - loss: 0.6461 - accuracy: 0.6531
# Epoch 46/50
# 614/614 [==============================] - 1s 2ms/step - loss: 0.6467 - accuracy: 0.6531
# Epoch 47/50
# 614/614 [==============================] - 1s 2ms/step - loss: 0.6465 - accuracy: 0.6531
# Epoch 48/50
# 614/614 [==============================] - 1s 2ms/step - loss: 0.6465 - accuracy: 0.6531
# Epoch 49/50
# 614/614 [==============================] - 1s 2ms/step - loss: 0.6465 - accuracy: 0.6531
# Epoch 50/50
# 614/614 [==============================] - 1s 2ms/step - loss: 0.6464 - accuracy: 0.6531

# %%
score = model.evaluate(x_test,y_test,verbose=1)
print(score)
# Out:
# 5/5 [==============================] - 0s 3ms/step - loss: 0.6523 - accuracy: 0.6429
# [0.6523080468177795, 0.6428571343421936]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive
